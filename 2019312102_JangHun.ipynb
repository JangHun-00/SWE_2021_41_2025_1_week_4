# %% [markdown]
# ## Task
# - Complete **isHappy** function following the description below
#
# ### Happy Number
# Write an algorithm to determine if a number **n** is happy.
#
# A **happy number** is a number defined by the following process:
#
# * Starting with any positive integer **n**, replace the number by the sum of the squares of its digits (refer to the testcase 1 below).
# * If we repeat the process, the number would reach 1 (where it will stay), or it would **loops endlessly in the cycle** without ever reaching 1.
# * Those numbers for which this process **ends in 1** are happy.
#
# Return **true** if n is a happy number, and **false** if not.
#
# Constraints:
# 1. 1 <= n <= $2^{31}$ - 1
# 2. Use Base-10 number system

# %%
def isHappy(n):
  # Complete the isHappy() function below
  # The function should return either True or False
  is_cycle = []
  next_number = n
  while True:
    digit_list = map(int, list(str(next_number)))
    next_number = sum([digit**2 for digit in digit_list])
    if next_number == 1:
      return True
    elif next_number in is_cycle:
      return False
    else:
      is_cycle.append(next_number)
  return False

# %%
isHappy(19)
# Out:
# True

# %%
isHappy(16)
# Out:
# False

# %% [markdown]
# **Testcase 1.**
#
# **Input**: 19
#
# **Output**: True
#
# **Explanation**:
#
# $1^2 + 9^2 = 82$
#
# $8^2 + 2^2 = 68$
#
# $6^2 + 8^2 = 100$
#
# $1^2 + 0^2 + 0^2 = 1$
#
# $1^2 = 1$ (reached 1 and will not change)

# %% [markdown]
# **Testcase 2.**
#
# **Input**: 16
#
# **Output**: False
#
# **Explanation**:
#
# $1^2 + 6^2 = 37$
#
# $3^2 + 7^2 = 58$
#
# $5^2 + 8^2 = 89$
#
# $8^2 + 9^2 = 145$
#
# $1^2 + 4^2 + 5^2 = 42$
#
# $4^2 + 2^2 = 20$
#
# $2^2 + 0^2 = 4$
#
# $4^2 = 16$
#
# $1^2 + 6^2 = 37$
#
# ... (endless loop of 16 ➜ 37 ➜ 58 ➜ 89 ➜ 145 ➜ 42 ➜ 20 ➜ 4 ➜ 16)
